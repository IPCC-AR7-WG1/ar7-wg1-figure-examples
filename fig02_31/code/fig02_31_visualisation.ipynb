
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import chl_analysis
# ----> 3 chl_analysis.process()
#
# File ~/ar7-wg1-input-data-example/fig02_31/code/chl_analysis.py:78, in process(j1, j2, ver, islice, year1)
#      76 print (ipos)
#      77 print("load")
# ---> 78 ds = load(i1=ipos, i2=ipos+islice, j1=j1, j2=j2, year1=year1, ver=ver)
#      79 ds = trend_analysis.add_trends(ds, fieldname="chlor_a")
#      80 fname = (f"ncfiles/OC-CCI_{year1}_2018_v{verstr}" +
#      81          f"_{j1:04}_{j2:04}_{ipos:04}_{ipos+1080:04}.nc")
#
# File ~/ar7-wg1-input-data-example/fig02_31/code/chl_analysis.py:66, in load(i1, i2, j1, j2, ver, year1, year2)
#      64     if not os.path.isfile(filename(dtm)):
#      65         download(dtm=dtm)
# ---> 66 ds = xr.open_mfdataset([filename(dtm) for dtm in dtmvec], parallel=True)
#      67 ds["chl"] = ds["chlor_a"]
#      68 return ds.isel(lon=slice(i1, i2), lat=slice(j1, j2))
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/api.py:1643, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1638     datasets = [preprocess(ds) for ds in datasets]
#    1640 if parallel:
#    1641     # calling compute here will return the datasets/file_objs lists,
#    1642     # the underlying datasets will still be stored as dask arrays
# -> 1643     datasets, closers = dask.compute(datasets, closers)
#    1645 # Combine all datasets, closing them in case of a ValueError
#    1646 try:
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/dask/base.py:656, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     653     postcomputes.append(x.__dask_postcompute__())
#     655 with shorten_traceback():
# --> 656     results = schedule(dsk, keys, **kwargs)
#     658 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:666, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     644 def open_dataset(
#     645     self,
#     646     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     663     autoclose=False,
#     664 ) -> Dataset:
#     665     filename_or_obj = _normalize_path(filename_or_obj)
# --> 666     store = NetCDF4DataStore.open(
#     667         filename_or_obj,
#     668         mode=mode,
#     669         format=format,
#     670         group=group,
#     671         clobber=clobber,
#     672         diskless=diskless,
#     673         persist=persist,
#     674         auto_complex=auto_complex,
#     675         lock=lock,
#     676         autoclose=autoclose,
#     677     )
#     679     store_entrypoint = StoreBackendEntrypoint()
#     680     with close_on_error(store):
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:452, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     448     kwargs["auto_complex"] = auto_complex
#     449 manager = CachingFileManager(
#     450     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     451 )
# --> 452 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:393, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     391 self._group = group
#     392 self._mode = mode
# --> 393 self.format = self.ds.data_model
#     394 self._filename = self.ds.filepath()
#     395 self.is_remote = is_remote_uri(self._filename)
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:461, in NetCDF4DataStore.ds(self)
#     459 @property
#     460 def ds(self):
# --> 461     return self._acquire()
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:455, in NetCDF4DataStore._acquire(self, needs_lock)
#     454 def _acquire(self, needs_lock=True):
# --> 455     with self._manager.acquire_context(needs_lock) as root:
#     456         ds = _nc4_require_group(root, self._group, self._mode)
#     457     return ds
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/hm1123/ar7-wg1-input-data-example/fig02_31/code/ncfiles/OC-CCI/ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-201510-fv4.2.nc'

# %%
chl_analysis.process(islice=270)
# Out:
# 0
# load
# downloading 1998-01-01
# downloading 1998-02-01
# downloading 1998-03-01
# downloading 1998-04-01
# downloading 1998-05-01
# downloading 1998-06-01
# downloading 1998-07-01
# downloading 1998-08-01
# downloading 1998-09-01
# downloading 1998-10-01
# downloading 1998-11-01
# downloading 1998-12-01
# downloading 1999-01-01
# downloading 1999-02-01
# downloading 1999-03-01
# downloading 1999-04-01
# downloading 1999-05-01
# downloading 1999-06-01
# downloading 1999-07-01
# downloading 1999-08-01
# downloading 1999-09-01
# downloading 1999-10-01
# downloading 1999-11-01
# downloading 1999-12-01
# downloading 2000-01-01
# downloading 2000-02-01
# downloading 2000-03-01
# downloading 2000-04-01
# downloading 2000-05-01
# downloading 2000-06-01
# downloading 2000-07-01
# downloading 2000-08-01
# downloading 2000-09-01
# downloading 2000-10-01
# downloading 2000-11-01
# downloading 2000-12-01
# downloading 2001-01-01
# downloading 2001-02-01
# downloading 2001-03-01
# downloading 2001-04-01
# downloading 2001-05-01
# downloading 2001-06-01
# downloading 2001-07-01
# downloading 2001-08-01
# downloading 2001-09-01
# downloading 2001-10-01
# downloading 2001-11-01
# downloading 2001-12-01
# downloading 2002-01-01
# downloading 2002-02-01
# downloading 2002-03-01
# downloading 2002-04-01
# downloading 2002-05-01
# downloading 2002-06-01
# downloading 2002-07-01
# downloading 2002-08-01
# downloading 2002-09-01
# downloading 2002-10-01
# downloading 2002-11-01
# downloading 2002-12-01
# downloading 2003-01-01
# downloading 2003-02-01
# downloading 2003-03-01
# downloading 2003-04-01
# downloading 2003-05-01
# downloading 2003-06-01
# downloading 2003-07-01
# downloading 2003-08-01
# downloading 2003-09-01
# downloading 2003-10-01
# downloading 2003-11-01
# downloading 2003-12-01
# downloading 2004-01-01
# downloading 2004-02-01
# downloading 2004-03-01
# downloading 2004-04-01
# downloading 2004-05-01
# downloading 2004-06-01
# downloading 2004-07-01
# downloading 2004-08-01
# downloading 2004-09-01
# downloading 2004-10-01
# downloading 2004-11-01
# downloading 2004-12-01
# downloading 2005-01-01
# downloading 2016-11-01
# downloading 2016-12-01
# downloading 2017-01-01
# downloading 2017-02-01
# downloading 2017-03-01
# downloading 2017-04-01
# downloading 2017-05-01
# downloading 2017-06-01
# downloading 2017-07-01
# downloading 2017-08-01
# downloading 2017-09-01
# downloading 2017-10-01
# downloading 2017-11-01
# downloading 2017-12-01
# downloading 2018-01-01
# downloading 2018-02-01
# downloading 2018-03-01
# downloading 2018-04-01
# downloading 2018-05-01
# downloading 2018-06-01
# downloading 2018-07-01
# downloading 2018-08-01
# downloading 2018-09-01
# downloading 2018-10-01
# downloading 2018-11-01
# downloading 2018-12-01
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/hm1123/ar7-wg1-input-data-example/fig02_31/code/ncfiles/OC-CCI/ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-201807-fv4.2.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '6dfa4353-22a2-4977-ac0e-8896510a9c95']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chl_analysis.process(islice=270)
#
# File ~/ar7-wg1-input-data-example/fig02_31/code/chl_analysis.py:78, in process(j1, j2, ver, islice, year1)
#      76 print (ipos)
#      77 print("load")
# ---> 78 ds = load(i1=ipos, i2=ipos+islice, j1=j1, j2=j2, year1=year1, ver=ver)
#      79 ds = trend_analysis.add_trends(ds, fieldname="chlor_a")
#      80 fname = (f"ncfiles/OC-CCI_{year1}_2018_v{verstr}" +
#      81          f"_{j1:04}_{j2:04}_{ipos:04}_{ipos+1080:04}.nc")
#
# File ~/ar7-wg1-input-data-example/fig02_31/code/chl_analysis.py:66, in load(i1, i2, j1, j2, ver, year1, year2)
#      64     if not os.path.isfile(filename(dtm)):
#      65         download(dtm=dtm)
# ---> 66 ds = xr.open_mfdataset([filename(dtm) for dtm in dtmvec], parallel=True)
#      67 ds["chl"] = ds["chlor_a"]
#      68 return ds.isel(lon=slice(i1, i2), lat=slice(j1, j2))
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/api.py:1643, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1638     datasets = [preprocess(ds) for ds in datasets]
#    1640 if parallel:
#    1641     # calling compute here will return the datasets/file_objs lists,
#    1642     # the underlying datasets will still be stored as dask arrays
# -> 1643     datasets, closers = dask.compute(datasets, closers)
#    1645 # Combine all datasets, closing them in case of a ValueError
#    1646 try:
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/dask/base.py:656, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     653     postcomputes.append(x.__dask_postcompute__())
#     655 with shorten_traceback():
# --> 656     results = schedule(dsk, keys, **kwargs)
#     658 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:666, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     644 def open_dataset(
#     645     self,
#     646     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#     663     autoclose=False,
#     664 ) -> Dataset:
#     665     filename_or_obj = _normalize_path(filename_or_obj)
# --> 666     store = NetCDF4DataStore.open(
#     667         filename_or_obj,
#     668         mode=mode,
#     669         format=format,
#     670         group=group,
#     671         clobber=clobber,
#     672         diskless=diskless,
#     673         persist=persist,
#     674         auto_complex=auto_complex,
#     675         lock=lock,
#     676         autoclose=autoclose,
#     677     )
#     679     store_entrypoint = StoreBackendEntrypoint()
#     680     with close_on_error(store):
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:452, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     448     kwargs["auto_complex"] = auto_complex
#     449 manager = CachingFileManager(
#     450     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     451 )
# --> 452 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:393, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     391 self._group = group
#     392 self._mode = mode
# --> 393 self.format = self.ds.data_model
#     394 self._filename = self.ds.filepath()
#     395 self.is_remote = is_remote_uri(self._filename)
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:461, in NetCDF4DataStore.ds(self)
#     459 @property
#     460 def ds(self):
# --> 461     return self._acquire()
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:455, in NetCDF4DataStore._acquire(self, needs_lock)
#     454 def _acquire(self, needs_lock=True):
# --> 455     with self._manager.acquire_context(needs_lock) as root:
#     456         ds = _nc4_require_group(root, self._group, self._mode)
#     457     return ds
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/hm1123/ar7-wg1-input-data-example/fig02_31/code/ncfiles/OC-CCI/ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-201807-fv4.2.nc'

# %%
chl_analysis.plot_chl_clim()

chl_analysis.plot_hatched_chl_trend()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 chl_analysis.plot_chl_clim()
#       3 chl_analysis.plot_hatched_chl_trend()
#
# File ~/ar7-wg1-input-data-example/fig02_31/code/chl_analysis.py:142, in plot_chl_clim(ds, ver)
#     140 verstr = str(ver.replace(".",""))
#     141 if ds is None:
# --> 142     ds = xr.open_mfdataset("ncfiles/OC-CCI_1998_2018_v42_0000_4320_*")
#     143 mp = projmap.Map("glob")
#     144 mp.style["landface"]="0.6"
#
# File ~/miniconda3/envs/esmvaltool_env/lib/python3.12/site-packages/xarray/backends/api.py:1597, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1594 paths = _find_absolute_paths(paths, engine=engine, **kwargs)
#    1596 if not paths:
# -> 1597     raise OSError("no files to open")
#    1599 paths1d: list[str | ReadBuffer]
#    1600 if combine == "nested":
#
# OSError: no files to open
